# %% [markdown]
# # Лабораторная работа №2
#
# ## Выполнил студент группы БСТ2004 Семенов Егор Максимович
#
# ### Задание №1

# %%
import random
import timeit

# генерация массива

def generate_mas(mas):
    n = int(input('Введите кол-во элементов: '))
    minimum = int(input("Введите минимальное значение генерируемых чисел: ", ))
    maximum = int(input("Введите максимальное значение генерируемых чисел: ", ))
    for i in range(n):
        A.append(random.randint(minimum,maximum))
    A.sort()
    print("\nСгенерирован начальный набор случайных данных: ", A)

A = []
generate_mas(A)
# Out:
# Введите кол-во элементов: 5
# Введите минимальное значение генерируемых чисел: -5
# Введите максимальное значение генерируемых чисел: 5
#
# Сгенерирован начальный набор случайных данных:  [-4, -3, 0, 4, 5]

# %%
# бинарный поиск
def binary_search(mas, x):
    # находим среднее значение массива, обозначим верхнюю и нижнюю границу
    middle = len(mas) // 2
    bottom_line = 0
    upper_line = len(mas) - 1
    # сравниваем искомое значение с серединой
    while mas[middle] != x and bottom_line <= upper_line:
        if x > mas[middle]:
            bottom_line = middle + 1
        else:
            upper_line = middle - 1
        # вычисляем индекс новой середины после сдвига одной из границ
        middle = (bottom_line + upper_line) // 2
    # проверка условия, если границы пересеклись
    if bottom_line > upper_line:
        return 'В сгенерированном массиве нет элемента с таким значением'
    else:
        return middle

A = []
generate_mas(A)
x = int(input("Введите элемент, который хотите найти: ", ))
starttime = timeit.default_timer()
print(binary_search(A, x))
endtime = timeit.default_timer()
print("Метод поиска работал:", endtime - starttime, "секунд")
a = int(input("Введите элемент, который хотите вставить: ", ))
print("Вывод массива со вставленным элементом: ")
print(insert_func(A, a))
b = int(input("Введите элемент, который хотите удалить: ", ))
print("Вывод массива с удаленным элементом: ")
print(delete_func(A, b))
# Out:
# Введите кол-во элементов: 12
# Введите минимальное значение генерируемых чисел: -12
# Введите максимальное значение генерируемых чисел: 12
#
# Сгенерирован начальный набор случайных данных:  [-12, -5, -5, -4, -1, 1, 3, 3, 4, 9, 10, 12]
# Введите элемент, который хотите найти: -4
# 3
# Метод поиска работал: 0.0001971000001503853 секунд
# Введите элемент, который хотите вставить: 108
# Вывод массива со вставленным элементом:
# [-12, -5, -5, -4, -1, 1, 3, 3, 4, 9, 10, 12, 108]
# Введите элемент, который хотите удалить: 1
# Вывод массива с удаленным элементом:
# [-12, -5, -5, -4, -1, 3, 3, 4, 9, 10, 12, 108]

# %%
# Бинарное дерево

# Создание корневого узла
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# Сортировка дерева
def inorder(root):
    if root is not None:
        # Обход левого поддерева
        inorder(root.left)
        # Обход корня
        print(str(root.data) + " ", end=' ')
        # Обход правого поддерева
        inorder(root.right)

# Вставка элемента
def insert_tree(node, data):
    # Если дерево пустое, то вернуть новый узел
    if node is None:
        return Node(data)
    # Переход в левое/правое поддерево и вставка узла
    if data < node.data:
        node.left = insert_tree(node.left, data)
    else:
        node.right = insert_tree(node.right, data)
    return node

# Поиск inorder-преемника
def minValueNode(node):
    current = node
    # Inorder-преемник - это найденный крайний левый лист
    while(current.left is not None):
        current = current.left
    return current

# Удаление узла
def deleteNode(root, data):
    # Если дерево пустое, возвращаем
    if root is None:
        return root
    # Необходимо найти узел, который нужно удалить
    if data < root.data:
        root.left = deleteNode(root.left, data)
    elif(data > root.data):
        root.right = deleteNode(root.right, data)
    else:
        # Если у узла только один дочерний узел или вообще их нет
        if root.left is None:
            temp = root.right
            root = None
            return temp
        elif root.right is None:
            temp = root.left
            root = None
            return temp
        # В случае когда у узла два дочерних узла, помещаем центрированного преемника на место узла, который нужно удалить
        temp = minValueNode(root.right)
        root.data = temp.data
        # Удаляем inorder-преемниа
        root.right = deleteNode(root.right, temp.data)
    return root

A = []
generate_mas(A)
root = None
for i in range(len(A)):
    root = insert_tree(root, A[i])
x = int(input("Введите элемент, который хотите найти: ", ))
starttime = timeit.default_timer()
inorder(root)
endtime = timeit.default_timer()
print("\nМетод поиска работал:", endtime - starttime, "секунд")
a = int(input("\nВведите элемент, который хотите вставить: ", ))
root = insert_tree(root, a)
print("\nВывод массива со вставленным элементом: ", end=' ')
inorder(root)
b = int(input("\nВведите элемент, который хотите удалить: ", ))
root = deleteNode(root, b)
print("\nВывод массива с удаленным элементом: ", end=' ')
inorder(root)
# Out:
# Введите кол-во элементов: 12
# Введите минимальное значение генерируемых чисел: -5
# Введите максимальное значение генерируемых чисел: 5
#
# Сгенерирован начальный набор случайных данных:  [-5, -5, -5, -4, -3, -3, -1, 0, 0, 3, 4, 4]
# Введите элемент, который хотите найти: 3
# -5  -5  -5  -4  -3  -3  -1  0  0  3  4  4
# Метод поиска работал: 0.00085529999978462 секунд
#
# Введите элемент, который хотите вставить: 165
#
# Вывод массива со вставленным элементом:  -5  -5  -5  -4  -3  -3  -1  0  0  3  4  4  165
# Введите элемент, который хотите удалить: -1
#
# Вывод массива с удаленным элементом:  -5  -5  -5  -4  -3  -3  0  0  3  4  4  165

# %%
# Фиббоначиев поиск
def fibonacci_search(mas, x):
    # первые два числа и третье выраженное суммой прошлых
    first_number = 0
    second_number = 1
    summary_number = first_number + second_number
    # наименьшее число в последовательности
    while summary_number < len(mas):
        first_number = second_number
        second_number = summary_number
        summary_number = first_number + second_number
    index = -1
    # пока в массиве есть элементы и значением суммы>1 делаем следующее
    while (summary_number > 1):
        # i ищем для того, чтобы понять на сколько вниз нам сдвигаться
        i = min(index+first_number, len(mas)-1)
        if mas[i] < x:
            # перемещаем  наши значения на два шага вниз и индекс становится индексом элемента
            summary_number = second_number
            second_number = first_number
            first_number = summary_number - second_number
            index = i
        elif mas[i] > x:
            # перемещаем наши значения на один шаг вниз
            summary_number = first_number
            second_number = second_number - first_number
            first_number = summary_number - second_number
        else:
            return i
    # проверяем значение
    if second_number and index < len(mas)-1 and mas[index+1] == x:
        return index+1
    return 'В сгенерированном массиве нет элемента с таким значением'

A = []
generate_mas(A)
x = int(input("Введите элемент, который хотите найти: ", ))
starttime = timeit.default_timer()
print(fibonacci_search(A, x))
endtime = timeit.default_timer()
print("Метод поиска работал:", endtime - starttime, "секунд")
a = int(input("Введите элемент, который хотите вставить: ", ))
print("Вывод массива со вставленным элементом: ")
print(insert_func(A, a))
b = int(input("Введите элемент, который хотите удалить: ", ))
print("Вывод массива с удаленным элементом: ")
print(delete_func(A, b))
# Out:
# Введите кол-во элементов: 11
# Введите минимальное значение генерируемых чисел: -8
# Введите максимальное значение генерируемых чисел: 16
#
# Сгенерирован начальный набор случайных данных:  [-7, -5, 0, 9, 11, 11, 11, 12, 13, 14, 15]
# Введите элемент, который хотите найти: 12
# 7
# Метод поиска работал: 0.00021150000020497828 секунд
# Введите элемент, который хотите вставить: 154
# Вывод массива со вставленным элементом:
# [-7, -5, 0, 9, 11, 11, 11, 12, 13, 14, 15, 154]
# Введите элемент, который хотите удалить: -5
# Вывод массива с удаленным элементом:
# [-7, 0, 9, 11, 11, 11, 12, 13, 14, 15, 154]

# %%
# Интерполяционный поиск
def interpolation_search(mas, x):
    start_index = 0
    last_index = len(mas)-1
    while start_index <= last_index and x >= mas[start_index] and x <= mas[last_index]:
        # вычисление вероятной позиции искомого элемента
        index = start_index + int(((float(last_index-start_index)/(mas[last_index]-mas[start_index]))*(x-mas[start_index])))
        # элемент найден
        if mas[index] == x:
            return index
        # пересчитываем индекс для праваого подмассива
        elif mas[index] < x:
            start_index = index + 1
        # пересчитываем индекс для левого подмассива
        else:
            last_index = index - 1
    return 'В сгенерированном массиве нет элемента с таким значением'

A = []
generate_mas(A)
x = int(input("Введите элемент, который хотите найти: ", ))
starttime = timeit.default_timer()
print(interpolation_search(A, x))
endtime = timeit.default_timer()
print("Метод поиска работал:", endtime - starttime, "секунд")
a = int(input("Введите элемент, который хотите вставить: ", ))
print("Вывод массива со вставленным элементом: ")
print(insert_func(A, a))
b = int(input("Введите элемент, который хотите удалить: ", ))
print("Вывод массива с удаленным элементом: ")
print(delete_func(A, b))
# Out:
# Введите кол-во элементов: 14
# Введите минимальное значение генерируемых чисел: -8
# Введите максимальное значение генерируемых чисел: 8
#
# Сгенерирован начальный набор случайных данных:  [-7, -7, -6, -5, -4, -1, 0, 1, 3, 3, 4, 6, 7, 7]
# Введите элемент, который хотите найти: 0
# 6
# Метод поиска работал: 0.00019040000006498303 секунд
# Введите элемент, который хотите вставить: 58
# Вывод массива со вставленным элементом:
# [-7, -7, -6, -5, -4, -1, 0, 1, 3, 3, 4, 6, 7, 7, 58]
# Введите элемент, который хотите удалить: 0
# Вывод массива с удаленным элементом:
# [-7, -7, -6, -5, -4, -1, 1, 3, 3, 4, 6, 7, 7, 58]

# %% [markdown]
# ### Задание №2

# %%
# Простое рехэширование

class Hash_Table:
    size = int(input("Введите размер хэш-таблицы: "))
    def __init__(self):
        self.data = [None] * self.size
    # Здесь получение содержимого баккета
    def __getitem__(self, key):
        h = self.get_Hash(key)
        try:
            while self.data[h]:
                if self.data[h] and self.data[h].get(key):
                    return self.data[h]
                h = self.get_Rehash(h)
        except IndexError:
            return
    # Здесь заполняется пустой баккет
    def __setitem__(self, key, value):
        h = self.get_Hash(key)
        if self.data[h] is None:
            self.data[h] = {key: value}
            return
        next_h = self.get_Rehash(h)
        try:
            while self.data[next_h] is not None:
                if self.data[next_h].get(key):
                    self.data[next_h].get(key)
                    break
                next_h = self.get_Rehash(next_h)
        except IndexError:
            raise
        self.data[next_h] = {key: value}
    def get_Hash(self, name):
        return len(name) % self.size
    def get_Rehash(self, oldhash):
        return oldhash + 1

# Заполнение хэш-таблицы двумя значениями
table = Hash_Table()
table[input('\nВведите ключ: ')] = input('\nВведите значение: ')
table[input('\nВведите ключ: ')] = input('\nВведите значение: ')
# Вывод одного из значений через ключ
print(table[input('\nВыберите значение по ключу: ')])
# Out:
# Введите размер хэш-таблицы: 4
#
# Введите значение: finally
#
# Введите ключ: mb
#
# Введите значение: finayll
#
# Введите ключ: 333
#
# Выберите значение по ключу: 333
# {'333': 'finayll'}

# %%
# Рехеширование с помощью псевдослучайных чисел

class randHash:
    def __init__(self):
        self.data = [None]*64   
    def randNumbers(self,i):
        R=[5]
        if len(R) - 1 < i:
            R.append(self.randNumbers(i - 1))
        return (8255 * R[i] + 239) % 64   
    def _hash(self, key,i):
        return (hash(key)+self.randNumbers(i))%(2**4)
    def addItem_Hash(self,key):
        i=0
        while self.data[self._hash(key,i)] != None and i<len(self.data):
            i+=1
        self.data[self._hash(key,i)] = key
        return self.data   
    def searchHash(self,key):
        i=0
        while self.data[self._hash(key,i)] != None and i<len(self.data):
            if self.data[self._hash(key,i)] == key:
                return 1
            i+=1
        return 0
    def deleteItem_Hash(self,key):
        i=0
        while self.data[self._hash(key,i)] != None and i<len(self.data):
            if self.data[self._hash(key,i)] == key:
                self.data.pop(self._hash(key,i))
                return self.data
            i+=1
        print("Такого элемента нет")
Digital = randHash()
Digital.addItem_Hash("6")
Digital.addItem_Hash("10")
Digital.addItem_Hash("8")
Digital.searchHash("6")
Digital.deleteItem_Hash("10")
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '8',
#  None,
#  '6',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# Метод цепочек

class ChainMethod:
    def __init__(self):
        self.data = [None]*64
    def _hash(self,key):
        return hash(key)%(2**4)
    def addItem(self, index, key):
        if self.data[index] is None:
            self.data[index] = [key]
            print("элемент был добавлен")
            return 1
        else:
            for i, item in enumerate(self.data[index]):
                if item == key:
                    self.data[index][i] = key
                    print("элемент не был добавлен")
                    return 0
            self.data[index].append(key)
            print("элемент был добавлен")
            return 1
    def searchChain(self,index,item):
        if self.data[index] is not None:
            if self.data[index] == [item]:
                print("Элемент был найден")
                return 1
            else:
                for i, item_ in enumerate(self.data[index]):
                    if self.data[index][i] == item:
                        print("Элемент был найден")
                        return 1
        else:
            print("Элемент не найден")
            return 0
    def deleteItem_Chain(self,index,item):
        if self.data[index] is not None:
            if self.data[index] == [item]:
                self.data[index] = None
                print("Элемент был удален")
                return 1
            else:
                for i, item_ in enumerate(self.data[index]):
                    if self.data[index][i] == item:
                        self.data[index].pop(i)
                        print("Элемент был удален")
                        return 1
        else:
            return 0

tableChain = ChainMethod()
tableChain.addItem(tableChain._hash("Пример"),"Пример")
tableChain.addItem(tableChain._hash("Тест"),"Тест")
tableChain.addItem(tableChain._hash("Тест примера"),"Тест примера")
tableChain.searchChain(tableChain._hash("Тест примера"),"Тест примера")
tableChain.deleteItem_Chain(tableChain._hash("Пример"),"Пример")
# Out:
# элемент был добавлен
# элемент был добавлен
# элемент был добавлен
# Элемент был найден
# Элемент был удален
# 1

# %% [markdown]
# ### Задание №3

# %%
# Ферзи

def setQueen(i,j):
    global cnt2
    cnt2 += 1
    for x in range(8):
        board[x][j] += 1
        board[i][x] += 1
        if 0 <= i + j - x < 8:
            board[i + j - x][x] += 1
        if 0 <= i - j + x < 8:
            board[i - j + x][x] += 1
    board[i][j] = -1

def removeQueen(i, j):
    for x in range (8):
        board[x][j] -= 1
        board[i][x] -= 1
        if 0 <= i + j - x < 8:
            board[i + j - x][x] -= 1
        if 0 <= i - j + x < 8:
            board[i - j + x][x] -= 1
    board[i][j] = 0

def printPosition():
    global cnt
    cnt += 1
    abc = 'abcdefgh'
    ans = []
    for i in range(8):
        for j in range(8):
            if board[i][j] == -1:
                ans.append(abc[j] + str(i + 1))
    print(', '.join(ans))

def solve(i):
    for j in range(8):
        if board[i][j] == 0:
            setQueen(i, j)
            if i == 7:
                printPosition()
            else:
                solve(i + 1)
            removeQueen (i, j)
            
board = [[0 for i in range(8)] for j in range(8)]
cnt = 0
cnt2 = 0
solve(0)
print(cnt)
print(cnt2)
# Out:
# a1, e2, h3, f4, c5, g6, b7, d8
# a1, f2, h3, c4, g5, d6, b7, e8
# a1, g2, d3, f4, h5, b6, e7, c8
# a1, g2, e3, h4, b5, d6, f7, c8
# b1, d2, f3, h4, c5, a6, g7, e8
# b1, e2, g3, a4, c5, h6, f7, d8
# b1, e2, g3, d4, a5, h6, f7, c8
# b1, f2, a3, g4, d5, h6, c7, e8
# b1, f2, h3, c4, a5, d6, g7, e8
# b1, g2, c3, f4, h5, e6, a7, d8
# b1, g2, e3, h4, a5, d6, f7, c8
# b1, h2, f3, a4, c5, e6, g7, d8
# c1, a2, g3, e4, h5, b6, d7, f8
# c1, e2, b3, h4, a5, g6, d7, f8
# c1, e2, b3, h4, f5, d6, g7, a8
# c1, e2, g3, a4, d5, b6, h7, f8
# c1, e2, h3, d4, a5, g6, b7, f8
# c1, f2, b3, e4, h5, a6, g7, d8
# c1, f2, b3, g4, a5, d6, h7, e8
# c1, f2, b3, g4, e5, a6, h7, d8
# c1, f2, d3, a4, h5, e6, g7, b8
# c1, f2, d3, b4, h5, e6, g7, a8
# c1, f2, h3, a4, d5, g6, e7, b8
# c1, f2, h3, a4, e5, g6, b7, d8
# c1, f2, h3, b4, d5, a6, g7, e8
# c1, g2, b3, h4, e5, a6, d7, f8
# c1, g2, b3, h4, f5, d6, a7, e8
# c1, h2, d3, g4, a5, f6, b7, e8
# d1, a2, e3, h4, b5, g6, c7, f8
# d1, a2, e3, h4, f5, c6, g7, b8
# d1, b2, e3, h4, f5, a6, c7, g8
# d1, b2, g3, c4, f5, h6, a7, e8
# d1, b2, g3, c4, f5, h6, e7, a8
# d1, b2, g3, e4, a5, h6, f7, c8
# d1, b2, h3, e4, g5, a6, c7, f8
# d1, b2, h3, f4, a5, c6, e7, g8
# d1, f2, a3, e4, b5, h6, c7, g8
# d1, f2, h3, b4, g5, a6, c7, e8
# d1, f2, h3, c4, a5, g6, e7, b8
# d1, g2, a3, h4, e5, b6, f7, c8
# d1, g2, c3, h4, b5, e6, a7, f8
# d1, g2, e3, b4, f5, a6, c7, h8
# d1, g2, e3, c4, a5, f6, h7, b8
# d1, h2, a3, c4, f5, b6, g7, e8
# d1, h2, a3, e4, g5, b6, f7, c8
# d1, h2, e3, c4, a5, g6, b7, f8
# e1, a2, d3, f4, h5, b6, g7, c8
# e1, a2, h3, d4, b5, g6, c7, f8
# e1, a2, h3, f4, c5, g6, b7, d8
# e1, b2, d3, f4, h5, c6, a7, g8
# e1, b2, d3, g4, c5, h6, f7, a8
# e1, b2, f3, a4, g5, d6, h7, c8
# e1, b2, h3, a4, d5, g6, c7, f8
# e1, c2, a3, f4, h5, b6, d7, g8
# e1, c2, a3, g4, b5, h6, f7, d8
# e1, c2, h3, d4, g5, a6, f7, b8
# e1, g2, a3, c4, h5, f6, d7, b8
# e1, g2, a3, d4, b5, h6, f7, c8
# e1, g2, b3, d4, h5, a6, c7, f8
# e1, g2, b3, f4, c5, a6, d7, h8
# e1, g2, b3, f4, c5, a6, h7, d8
# e1, g2, d3, a4, c5, h6, f7, b8
# e1, h2, d3, a4, c5, f6, b7, g8
# e1, h2, d3, a4, g5, b6, f7, c8
# f1, a2, e3, b4, h5, c6, g7, d8
# f1, b2, g3, a4, c5, e6, h7, d8
# f1, b2, g3, a4, d5, h6, e7, c8
# f1, c2, a3, g4, e5, h6, b7, d8
# f1, c2, a3, h4, d5, b6, g7, e8
# f1, c2, a3, h4, e5, b6, d7, g8
# f1, c2, e3, g4, a5, d6, b7, h8
# f1, c2, e3, h4, a5, d6, b7, g8
# f1, c2, g3, b4, d5, h6, a7, e8
# f1, c2, g3, b4, h5, e6, a7, d8
# f1, c2, g3, d4, a5, h6, b7, e8
# f1, d2, a3, e4, h5, b6, g7, c8
# f1, d2, b3, h4, e5, g6, a7, c8
# f1, d2, g3, a4, c5, e6, b7, h8
# f1, d2, g3, a4, h5, b6, e7, c8
# f1, h2, b3, d4, a5, g6, e7, c8
# g1, a2, c3, h4, f5, d6, b7, e8
# g1, b2, d3, a4, h5, e6, c7, f8
# g1, b2, f3, c4, a5, d6, h7, e8
# g1, c2, a3, f4, h5, e6, b7, d8
# g1, c2, h3, b4, e5, a6, f7, d8
# g1, d2, b3, e4, h5, a6, c7, f8
# g1, d2, b3, h4, f5, a6, c7, e8
# g1, e2, c3, a4, f5, h6, b7, d8
# h1, b2, d3, a4, g5, e6, c7, f8
# h1, b2, e3, c4, a5, g6, d7, f8
# h1, c2, a3, f4, b5, e6, g7, d8
# h1, d2, a3, c4, f5, b6, g7, e8
# 92
# 2056
